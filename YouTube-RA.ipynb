# %%
import pandas as pd
import os

# %%
#import file for Nominees list

file = os.path.join('List_of_Nominations.csv')

nominees_list = pd.read_csv(file)
nominees_list.head()
# Out:
#    Year RECORD OF THE YEAR BEST NEW ARTIST    SONG OF THE YEAR  \
# 0  2018            Redbone    Alessia Cara           Despacito
# 1  2018          Despacito          Khalid                4:44
# 2  2018  The Story of O.J.    Lil Uzi Vert              Issues
# 3  2018             Humble  Julia Michaels      1-800-273-8255
# 4  2018          24k Magic             SZA  That's What I Like
#
#   ALBUM OF THE YEAR
# 0  Awaken, My Love!
# 1              4:44
# 2             Damn.
# 3         Melodrama
# 4         24k Magic

# %%
#Create a DataFrame for the Nominees list

nominees_list_df = pd.DataFrame(nominees_list)
nominees_list_df.head()
# Out:
#    Year RECORD OF THE YEAR BEST NEW ARTIST    SONG OF THE YEAR  \
# 0  2018            Redbone    Alessia Cara           Despacito
# 1  2018          Despacito          Khalid                4:44
# 2  2018  The Story of O.J.    Lil Uzi Vert              Issues
# 3  2018             Humble  Julia Michaels      1-800-273-8255
# 4  2018          24k Magic             SZA  That's What I Like
#
#   ALBUM OF THE YEAR
# 0  Awaken, My Love!
# 1              4:44
# 2             Damn.
# 3         Melodrama
# 4         24k Magic

# %%
#import file for Winners list

file = os.path.join('Grammy_winner_list.csv')

winners_list = pd.read_csv(file)
winners_list.head()

#Create a DataFrame for the Nominees list

winners_list_df = pd.DataFrame(winners_list)
winners_list_df
# Out:
#    Year                RECORD OF THE YEAR          BEST NEW ARTIST  \
# 0  2017                             Hello        Chance The Rapper
# 1  2016                       Uptown Funk           Meghan Trainor
# 2  2015  Stay With Me (Darkchild Version)                Sam Smith
# 3  2014                         Get Lucky  Macklemore & Ryan Lewis
# 4  2013      Somebody That I Used to Know                      Fun
# 5  2012               Rolling In The Deep                 Bon Iver
# 6  2011                      Need You Now       Esperanza Spalding
# 7  2010                      Use Somebody           Zac Brown Band
# 8  2009            Please Read the Letter                    Adele
# 9  2008                             Rehab            Amy Winehouse
#
#                    SONG OF THE YEAR
# 0                             Hello
# 1                 Thinking Out Loud
# 2  Stay With Me (Darkchild Version)
# 3                            Royals
# 4                      We Are Young
# 5               Rolling In The Deep
# 6                      Need You Now
# 7  Single Ladies (Put A Ring On It)
# 8                      Viva la Vida
# 9                             Rehab
