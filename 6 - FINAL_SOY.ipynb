# %%
# Import Dependencies
import matplotlib.pyplot as plt
import requests as req
import pandas as pd
import numpy as np
import seaborn
import random
import json
import os

# %%
#import file for Nominees list

nominees_list = pd.DataFrame.from_csv("/Users/jenny/Desktop/Updated_List_Nominations.csv", index_col=None, encoding='utf-8')

winners_list = pd.DataFrame.from_csv("Grammy_Winner_List.csv", index_col=None, encoding='utf-8')

winners_list.head()
# Out:
#    Year                RECORD OF THE YEAR                   ROY ARTIST  \
# 0  2017                             Hello                        Adele
# 1  2016                       Uptown Funk                   Bruno Mars
# 2  2015  Stay With Me (Darkchild Version)                    Sam Smith
# 3  2014                         Get Lucky  Daft Punk Pharrell Williams
# 4  2013      Somebody That I Used to Know                 Gotye Kimbra
#
#            BEST NEW ARTIST                  SONG OF THE YEAR  \
# 0        Chance The Rapper                             Hello
# 1           Meghan Trainor                 Thinking Out Loud
# 2                Sam Smith  Stay With Me (Darkchild Version)
# 3  Macklemore & Ryan Lewis                            Royals
# 4                      Fun                      We Are Young
#
#           SOY ARTIST
# 0              Adele
# 1         Ed Sheeran
# 2          Sam Smith
# 3              Lorde
# 4  Fun Janelle Monae

# %%
# Combine related columns and create a new combined column

nominees_list['ROY Combined'] = nominees_list['RECORD OF THE YEAR'] + " " + nominees_list['ROY ARTIST']
nominees_list['SOY Combined'] = nominees_list['SONG OF THE YEAR'] + " " + nominees_list['SOY ARTIST']

nominees_list.head()

# Generate a new list with combined data

rev_nominees_list = nominees_list[["Year", "ROY Combined", "SOY Combined", "BEST NEW ARTIST"]]
rev_nominees_temp = nominees_list[["SOY Combined", "SONG OF THE YEAR"]]

rev_winners_list = winners_list[["SONG OF THE YEAR", "SOY ARTIST"]]

rev_nominees_temp.head()
rev_nominees_temp = rev_nominees_temp.rename(columns={"SOY Combined":"Song"})
rev_winners_list.head()
# Out:
#                    SONG OF THE YEAR         SOY ARTIST
# 0                             Hello              Adele
# 1                 Thinking Out Loud         Ed Sheeran
# 2  Stay With Me (Darkchild Version)          Sam Smith
# 3                            Royals              Lorde
# 4                      We Are Young  Fun Janelle Monae

# %%
#Create a DataFrame for the Nominees list

rev_nominees_list_df = pd.DataFrame(rev_nominees_list)
rev_nominees_list_df.head()

#Split the DataFrame by category
#Record of the Year
records_list_df = rev_nominees_list_df[["Year", "ROY Combined"]]
records_list_df.head()

#Split the DataFrame by category
new_artist_list_df = rev_nominees_list_df[["Year", "BEST NEW ARTIST"]]
new_artist_list_df.head()

#Split the DataFrame by category
song_list_df = rev_nominees_list_df[["Year", "SOY Combined"]]
song_list_df.head()
# Out:
#    Year                                     SOY Combined
# 0  2018  Despacito Luis Fonsi Daddy Yankee Justin Bieber
# 1  2018                                       4:44 JAY-Z
# 2  2018                            Issues Julia Michaels
# 3  2018         1-800-273-8255 Logic Alessia Cara Khalid
# 4  2018                    That's What I Like Bruno Mars

# %%
# Drops NA values in df

song_list_df = song_list_df.dropna()

# %%
song_list_df
# Out:
#     Year                                       SOY Combined
# 0   2018    Despacito Luis Fonsi Daddy Yankee Justin Bieber
# 1   2018                                         4:44 JAY-Z
# 2   2018                              Issues Julia Michaels
# 3   2018           1-800-273-8255 Logic Alessia Cara Khalid
# 4   2018                      That's What I Like Bruno Mars
# 5   2017                                  Formation Beyonce
# 6   2017                                        Hello Adele
# 7   2017                 I Took A Pill In Ibiza Mike Posner
# 8   2017                        Love Yourself Justin Bieber
# 9   2017                               7 Years Lukas Graham
# 10  2016                             Alright Kendrick Lamar
# 11  2016                           Blank Space Taylor Swift
# 12  2016                         Girl Crush Little Big Town
# 13  2016             See You Again Wiz Khalifa Charlie Puth
# 14  2016                       Thinking Out Loud Ed Sheeran
# 15  2015                                     Chandelier Sia
# 16  2015                 All About That Bass Meghan Trainor
# 17  2015                          Shake It Off Taylor Swift
# 18  2015         Stay With Me (Darkchild Version) Sam Smith
# 19  2015                           Take Me To Chursh Hozier
# 20  2014                                       Royals Lorde
# 21  2014              Just Give Me a Reason Pink Nate Ruess
# 22  2014                    Locked Out of Heaven Bruno Mars
# 23  2014                                    Roar Katy Perry
# 24  2014     Same Love Macklemore & Ryan Lewis Mary Lambert
# 25  2013                              The A Team Ed Sheeran
# 26  2013                                       Adorn Miguel
# 27  2013                     Call Me Maybe Carly Rae Jepsen
# 28  2013  Stronger (What Doesn_Ñét Kill You) Kelly Clarkson
# 29  2013                     We Are Young Fun Janelle Monae
# 31  2012  All Of The Lights Kanye West Rihanna Kid Cudi ...
# 32  2012                            The Cave Mumford & Sons
# 33  2012                                 Grenade Bruno Mars
# 34  2012                                  Holocene Bon Iver
# 35  2012                          Rolling In The Deep Adele
# 36  2011  Beg Steal Or Borrow Ray LaMontagne The Pariah ...
# 37  2011                                _Ñ_You Cee Lo Green
# 38  2011            The House That Built Me Miranda Lambert
# 39  2011                Love The Way You Lie Eminem Rihanna
# 40  2011                       Need You Now Lady Antebellum
# 41  2010                               Poker Face Lady Gaga
# 42  2010                               Pretty Wings Maxwell
# 43  2010           Single Ladies (Put A Ring On It) Beyonce
# 44  2010                         Use Somebody Kings of Leon
# 45  2010                    You Belong With Me Taylor Swift
# 46  2009                    American Boy Estelle Kanye West
# 47  2009                            Chasing Pavements Adele
# 48  2009                               I'm Yours Jason Mraz
# 49  2009                           Love Song Sara Bareilles
# 50  2009                              Viva la Vida Coldplay
# 51  2008                  Before He Cheats Carrie Underwood
# 52  2008                   Hey There Delilah Plain White Ts
# 53  2008                     Like A Star Corinne Bailey Rae
# 54  2008                                Rehab Amy Winehouse
# 55  2008                             Umbrella Rihanna JAY-Z

# %% [markdown]
# ## 2017 SOY Nominees

# %%
year = 2017

# %%
pub_before = year
pub_after = year - 1

# %%
songs = song_list_df.loc[(song_list_df['Year']==year)]

# %%
SOY = songs['SOY Combined']

# %%
# Obtain search data and construct dictionary

# Search URL
url = 'https://www.googleapis.com/youtube/v3/search'

api_key = 'AIzaSyBIsDwNMWPe4ZMVlpVcPpZTVaM45h3Umdo'

#Set Parameters
params = {'key': 'AIzaSyBJUQCRS-O5wAMAoILxVo8THZf9D4Ex3Zc',
         'part': 'snippet',
         'maxResults': 50,
         'publishedAfter': f'{pub_after}-10-01T00:00:00Z', ## REMEMBER TO CHANGE YEARS 
         'publishedBefore': f'{pub_before}-09-30T00:00:00Z',
         'order': 'viewCount',
         'q': ''}

search_data = {'Song':[],
              'Title':[],
              'VideoId':[],
              'Channel_Title':[],
              'ChannelId':[],
              'PublishedAt':[],
               'Year': [] }

for search_term in SOY:
    params['q'] = search_term
    response = req.get(url, params=params).json()
    for search_result in response['items']:
        try:
            search_data['Year'].append(year)
            search_data['Song'].append(search_term)
            search_data['Title'].append(search_result['snippet']['title'])
            search_data['VideoId'].append(search_result['id']['videoId'])
            search_data['Channel_Title'].append(search_result['snippet']['channelTitle'])
            search_data['ChannelId'].append(search_result['snippet']['channelId'])
            search_data['PublishedAt'].append(search_result['snippet']['publishedAt'])
        except KeyError:
            print("Missing videoID")
    #print(json.dumps(response['items'][0]['id']['videoId']))
# Out:
# Missing videoID
# Missing videoID
# Missing videoID

# %%
# Title: response['items'][0]['snippet']['title']
# VideoId: response['items'][0]['id']['videoId']
# publishedAt: 

# test_df = pd.DataFrame(search_data)

# test_df

test_df = pd.DataFrame.from_dict(search_data, orient='index').transpose()

# %%
title_vid = test_df[['Song', 'Title', 'VideoId']]

# %%
url_vid = 'https://www.googleapis.com/youtube/v3/videos'

params = {'key': 'AIzaSyDD5By7jCByawiGgRjOghbig8_N7hhesDg',
         'part': 'statistics',
         'id': ''}

grammy_stats_df = {}

for song, title, vid_id in title_vid.itertuples(index=False):
    try:
        params['id'] = vid_id
        response = req.get(url_vid, params=params).json()
        grammy_stats_df[song, title] = response['items'][0]['statistics']
    except KeyError:
        print(f'{title} has no video ID')
# Out:
# Lukas Graham   7 Years Saxophone Sheet Music Play Along has no video ID
# 7Years - Lukas Graham Cover Tom Room39 REACTION ✔ has no video ID
# Lukas Graham - 7 Years (Shidoky Remix) VERSÃO FUNK has no video ID

# %%
grammy_stats_2017 = pd.DataFrame(grammy_stats_df).transpose()

# %%
grammy_stats_2017.isnull().sum()
# Out:
# commentCount     2
# dislikeCount     4
# favoriteCount    0
# likeCount        4
# viewCount        0
# dtype: int64

# %% [markdown]
# ## BIG LOOP TEST

# %%
years = [2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008]

# Search URL
url = 'https://www.googleapis.com/youtube/v3/search'

api_key = 'AIzaSyArT3hBre9oP_akhIrftGdvSL0tKopslS8'

#Set Parameters

grammy_stats_df = {}

for year in years:
    songs = song_list_df.loc[(song_list_df['Year']==year)]
    SOY = songs['SOY Combined']
    
    pub_before = year
    pub_after = year - 1
    songs = song_list_df.loc[(song_list_df['Year']==year)]
    params = {'key': 'AIzaSyArT3hBre9oP_akhIrftGdvSL0tKopslS8',
         'part': 'snippet',
         'maxResults': 50,
         'publishedAfter': f'{pub_after}-10-01T00:00:00Z', ## REMEMBER TO CHANGE YEARS 
         'publishedBefore': f'{pub_before}-09-30T00:00:00Z',
         'order': 'viewCount',
         'q': ''}

    search_data = {'Song':[],
              'Title':[],
              'VideoId':[],
              'Channel_Title':[],
              'ChannelId':[],
              'PublishedAt':[],
               'Year': [] }
    for search_term in SOY:
        params['q'] = search_term
        response = req.get(url, params=params).json()
        for search_result in response['items']:
            try:
                search_data['Year'].append(year)
                search_data['Song'].append(search_term)
                search_data['Title'].append(search_result['snippet']['title'])
                search_data['VideoId'].append(search_result['id']['videoId'])
                search_data['Channel_Title'].append(search_result['snippet']['channelTitle'])
                search_data['ChannelId'].append(search_result['snippet']['channelId'])
                search_data['PublishedAt'].append(search_result['snippet']['publishedAt'])
            except KeyError:
                print("Missing videoID")


    test_df = pd.DataFrame.from_dict(search_data, orient='index').transpose()

    title_vid = test_df[['Song', 'Title', 'VideoId', 'Year']]

    url_vid = 'https://www.googleapis.com/youtube/v3/videos'

    params = {'key': 'AIzaSyArT3hBre9oP_akhIrftGdvSL0tKopslS8',
             'part': 'statistics',
             'id': ''}

    for song, title, vid_id, year in title_vid.itertuples(index=False):
        try:
            params['id'] = vid_id
            response = req.get(url_vid, params=params).json()
            grammy_stats_df[song, title, year] = response['items'][0]['statistics']
        except KeyError:
            print(f'{title} has no video ID')
    grammy_stats = pd.DataFrame(grammy_stats_df).transpose()

    grammy_stats.isnull().sum()
# Out:
# Missing videoID
# Bruno Mars 11.11.17 the Forum LA - Thats What I Like has no video ID
# Missing videoID
# Missing videoID
# Missing videoID
# Lukas Graham   7 Years Saxophone Sheet Music Play Along has no video ID
# 7Years - Lukas Graham Cover Tom Room39 REACTION ✔ has no video ID
# Lukas Graham - 7 Years (Shidoky Remix) VERSÃO FUNK has no video ID
# Missing videoID
# Missing videoID
# Ed Sheeran♥ Thinking Out Loud♥ (tradução) has no video ID
# Thinking Out Loud (Ed Sheeran´song) - Vintage Reggae Café - The New Album 2016 has no video ID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Matt McAndrew - Take Me To Church - Studio Version - The Voice 7 has no video ID
# HOZIER - Take Me To Church | T in the Park 2015 has no video ID
# Hozier - Take Me To Church (Subtitulos en Español) has no video ID
# Hozier - Take Me To Church - How to Play On Guitar Chords - Easy Guitar Lessons has no video ID
# "Take Me to Church" - Hozier (Cello Cover by Nicholas Yee) has no video ID
# Hozier Take Me To Church live performance At Billboard Music Awards 2015 @BBMAs 2015.5.17 has no video ID
# Take Me To Church - Hozier (Ukulele Tutorial) has no video ID
# Take Me to Church // Hozier // Cover by Andie has no video ID
# Take Me to Church - Hozier - Acoustic Piano Cover - Music Video has no video ID
# Take Me To Church - Hozier (Enisa Cover) has no video ID
# Hozier - Take Me To Church (Social Repose Cover) has no video ID
# Becky Hill - Take Me To Church (Hozier Cover) has no video ID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Mary Lambert Interview 2013 has no video ID
# TLC vs. Macklemore & Ryan Lewis ft. Mary Lambert - Creepy Love has no video ID
# LyricsTube has no video ID
# MACKLEMORE & RYAN LEWIS SAME LOVE FT. MARY LAMBERT has no video ID
# SAME LOVE - MACKLEMORE  feat. MARY LAMBERT - Lyrics has no video ID
# Missing videoID
# Missing videoID
# Missing videoID
# DJ R124L - Fun Feat Janelle Monae - We Are Young (House Music) has no video ID
# Fun 'We Are Young' On The Late Late Show 2012 has no video ID
# Fun feat. Janelle Monáe- We Are Young (Drum Cover) has no video ID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Rolling in the Deep by Adele Meets Metal has no video ID
# Fireworks Show - FWsim Simulator - Rolling In The Deep, Adele has no video ID
# VAZQUEZ SOUNDS PARODY - ROLLING IN THE POOP - ROLLING IN THE DEEP ADELE COVER BY LATEX SOUNDS has no video ID
# Adele-Rolling In The Deep(Jazz Metal Version) has no video ID
# Adele "Rolling in the deep" live at he royal albert hall has no video ID
# Kathleen Reiter- Rolling In The Deep (Adele Cover) The Voice Israel has no video ID
# Adele - Rolling in the Deep LIVE cover by Megan Lee has no video ID
# 박지민 Rolling in the deep has no video ID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Lady Antebellum - Need You Now(Collaboration with Jasmine Clarke) has no video ID
# Need You Now - Lady Antebellum Piano Cover has no video ID
# Need You Now - Lady Antebellum (TRADUÇÃO) has no video ID
# Travis Garland JoJo perform Lady Antebellum Need You Now has no video ID
# Awi rafael & shila amzah - Need You Now(Lady Antebellum ) has no video ID
# Jan Dulles en Lisa zingen Need you now van Lady Antebellum has no video ID
# TRADUZIONE DI Lady Antebellum - Need you now has no video ID
# Lady Antebellum - Need You Now tradução (legendado) has no video ID
# Savannah Outen & Boyce Avenue 'Need you Now' By Lady Antebellum has no video ID
# Lady Antebellum- Need You Now. ( Legendado) has no video ID
# Need You Now - Lady Antebellum Cover - Hayley Legg has no video ID
# Lady Antebellum-Need You Now  live @ Sydney Ent Cent has no video ID
# Lady Antebellum - Need You Now (Acoustic Guitar Solo) has no video ID
# Need You Now - Lady Antebellum Piano Tribute has no video ID
# Lady Antebellum - Need You Now - ( PART MALE- PAIO ) Final test has no video ID
# Lady Antebellum performance "Need You Now" in 53rd Grammy Awards 2011 has no video ID
# Need You Now(iTunes Session) by Lady Antebellum (With lyrics) has no video ID
# Need you now Lady Antebellum [ W/Lyrics] has no video ID
# Missing videoID
# Missing videoID
# PS22 Brielle "You Belong With Me" Taylor Swift has no video ID
# Taylor Swift You Belong With Me (Official Music Video) has no video ID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Viva La Vida Remix Coldplay has no video ID
# Coldplay - Viva La Vida (keyboard cover) has no video ID
# Coldplay - Viva La Vida (MTV Movie Awards 2008)*** has no video ID
# Coldplay-Satriani-Verdes-Stevens Viva La Vida Plagiarism? has no video ID
# Viva la Vida - Brass Quintet Arrangement has no video ID
# Coldplay - Viva La Vida en vivo has no video ID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Comenius Kids Chor - Umbrella (Rihanna) has no video ID
# TÕHG Playback 2008 - 09 - Umbrella has no video ID
# Rihanna - Umbrella has no video ID
# UmbreLLa feat. Marian Rivera has no video ID
# Rihannah ft Jay z - Unberella male singer has no video ID
# Rihanna & Chris Brown Ft JayZ - Cinderella Under My Umbrella has no video ID
# Jump StarZ - Umbrella has no video ID
# Rihanna - Umbrella (jody den broeder lush radio edit) [HQ] has no video ID
# Umbrella/Cinderella - Chris Brown Remix Ft Rihanna and Jay-Z has no video ID
# Umbrella- Rihanna  *with lyrics* has no video ID
# Rihanna-Umbrella With Lyrics (Featuring Jay-Z) has no video ID
# Rihanna - Umbrella (Chipmunk Version) has no video ID
# Nsync- Umbrella Remix has no video ID
# Standard Of Living - Umbrella (Cover of Rihanna & Jay-Z) has no video ID
# Umbrella Remix-UNC Loreleis has no video ID

# %%
grammy_stats.head()
# Out:
#                                                                                                  commentCount  \
# 1-800-273-8255 Logic Alessia Cara Khalid 【Nightcore】→ 1-800-273-8255 ( Rock Cover ) || L... 2018          500
# 4:44 JAY-Z                               "Kung Fu Kenny" *FREE* Kendrick Lamar feat Jay ... 2018            2
#                                          "Matthew 4:44" *FREE* Kanye West feat Jay Z 4:4... 2018            2
#                                          "Paradise" *FREE* Jay Z 4:44 feat Kendrick Lama... 2018            6
#                                          4:44 Instrumental | Reprod. By Q.                  2018          116
#
#                                                                                                  dislikeCount  \
# 1-800-273-8255 Logic Alessia Cara Khalid 【Nightcore】→ 1-800-273-8255 ( Rock Cover ) || L... 2018          171
# 4:44 JAY-Z                               "Kung Fu Kenny" *FREE* Kendrick Lamar feat Jay ... 2018            0
#                                          "Matthew 4:44" *FREE* Kanye West feat Jay Z 4:4... 2018            1
#                                          "Paradise" *FREE* Jay Z 4:44 feat Kendrick Lama... 2018            0
#                                          4:44 Instrumental | Reprod. By Q.                  2018           15
#
#                                                                                                  favoriteCount  \
# 1-800-273-8255 Logic Alessia Cara Khalid 【Nightcore】→ 1-800-273-8255 ( Rock Cover ) || L... 2018             0
# 4:44 JAY-Z                               "Kung Fu Kenny" *FREE* Kendrick Lamar feat Jay ... 2018             0
#                                          "Matthew 4:44" *FREE* Kanye West feat Jay Z 4:4... 2018             0
#                                          "Paradise" *FREE* Jay Z 4:44 feat Kendrick Lama... 2018             0
#                                          4:44 Instrumental | Reprod. By Q.                  2018             0
#
#                                                                                                  likeCount  \
# 1-800-273-8255 Logic Alessia Cara Khalid 【Nightcore】→ 1-800-273-8255 ( Rock Cover ) || L... 2018     16651
# 4:44 JAY-Z                               "Kung Fu Kenny" *FREE* Kendrick Lamar feat Jay ... 2018         5
#                                          "Matthew 4:44" *FREE* Kanye West feat Jay Z 4:4... 2018        14
#                                          "Paradise" *FREE* Jay Z 4:44 feat Kendrick Lama... 2018       116
#                                          4:44 Instrumental | Reprod. By Q.                  2018      1082
#
#                                                                                                  viewCount
# 1-800-273-8255 Logic Alessia Cara Khalid 【Nightcore】→ 1-800-273-8255 ( Rock Cover ) || L... 2018    796254
# 4:44 JAY-Z                               "Kung Fu Kenny" *FREE* Kendrick Lamar feat Jay ... 2018      2455
#                                          "Matthew 4:44" *FREE* Kanye West feat Jay Z 4:4... 2018      3256
#                                          "Paradise" *FREE* Jay Z 4:44 feat Kendrick Lama... 2018      2484
#                                          4:44 Instrumental | Reprod. By Q.                  2018     51721

# %%
os.chdir("/Users/jenny/Desktop/Team5")
path=r"/Users/jenny/Desktop/Team5"
#WithCompound.to_csv(os.path.join(path,r'WithCompound_1.csv'))
#SCR.to_csv(os.path.join(path,r'SCR_1.csv'))
#BAG3.to_csv(os.path.join(path,r'BAG3_1.csv'))

writer = pd.ExcelWriter(path+"Song_Of_The_Year_All_Years.xlsx")
grammy_stats.to_excel(writer, sheet_name='List of Nominees')
writer.save()

# %% [markdown]
# -------------------------------

# %%
updated_stats_df = grammy_stats.reset_index()

renamed_stats_df = updated_stats_df.rename(columns={'level_0': 'Song', 
                                                    'level_1': 'YoutubeSongName',
                                                    'level_2': 'Year'})

renamed_stats_df['viewCount'] = renamed_stats_df['viewCount'].convert_objects(convert_numeric=True)
renamed_stats_df['commentCount'] = renamed_stats_df['commentCount'].convert_objects(convert_numeric=True)
renamed_stats_df['dislikeCount'] = renamed_stats_df['dislikeCount'].convert_objects(convert_numeric=True)
renamed_stats_df['favoriteCount'] = renamed_stats_df['favoriteCount'].convert_objects(convert_numeric=True)
renamed_stats_df['likeCount'] = renamed_stats_df['likeCount'].convert_objects(convert_numeric=True)

renamed_stats_df
# Out:
# /Users/jenny/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:7: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/jenny/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:8: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/jenny/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:9: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/jenny/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:10: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/jenny/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:11: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#                                           Song  \
# 0     1-800-273-8255 Logic Alessia Cara Khalid
# 1                                   4:44 JAY-Z
# 2                                   4:44 JAY-Z
# 3                                   4:44 JAY-Z
# 4                                   4:44 JAY-Z
# 5                                   4:44 JAY-Z
# 6                                   4:44 JAY-Z
# 7                                   4:44 JAY-Z
# 8                                   4:44 JAY-Z
# 9                                   4:44 JAY-Z
# 10                                  4:44 JAY-Z
# 11                                  4:44 JAY-Z
# 12                                  4:44 JAY-Z
# 13                                  4:44 JAY-Z
# 14                                  4:44 JAY-Z
# 15                                  4:44 JAY-Z
# 16                                  4:44 JAY-Z
# 17                                  4:44 JAY-Z
# 18                                  4:44 JAY-Z
# 19                                  4:44 JAY-Z
# 20                                  4:44 JAY-Z
# 21                                  4:44 JAY-Z
# 22                                  4:44 JAY-Z
# 23                                  4:44 JAY-Z
# 24                                  4:44 JAY-Z
# 25                                  4:44 JAY-Z
# 26                                  4:44 JAY-Z
# 27                                  4:44 JAY-Z
# 28                                  4:44 JAY-Z
# 29                                  4:44 JAY-Z
# ...                                        ...
# 2465                       _Ñ_You Cee Lo Green
# 2466                       _Ñ_You Cee Lo Green
# 2467                       _Ñ_You Cee Lo Green
# 2468                       _Ñ_You Cee Lo Green
# 2469                       _Ñ_You Cee Lo Green
# 2470                       _Ñ_You Cee Lo Green
# 2471                       _Ñ_You Cee Lo Green
# 2472                       _Ñ_You Cee Lo Green
# 2473                       _Ñ_You Cee Lo Green
# 2474                       _Ñ_You Cee Lo Green
# 2475                       _Ñ_You Cee Lo Green
# 2476                       _Ñ_You Cee Lo Green
# 2477                       _Ñ_You Cee Lo Green
# 2478                       _Ñ_You Cee Lo Green
# 2479                       _Ñ_You Cee Lo Green
# 2480                       _Ñ_You Cee Lo Green
# 2481                       _Ñ_You Cee Lo Green
# 2482                       _Ñ_You Cee Lo Green
# 2483                       _Ñ_You Cee Lo Green
# 2484                       _Ñ_You Cee Lo Green
# 2485                       _Ñ_You Cee Lo Green
# 2486                       _Ñ_You Cee Lo Green
# 2487                       _Ñ_You Cee Lo Green
# 2488                       _Ñ_You Cee Lo Green
# 2489                       _Ñ_You Cee Lo Green
# 2490                       _Ñ_You Cee Lo Green
# 2491                       _Ñ_You Cee Lo Green
# 2492                       _Ñ_You Cee Lo Green
# 2493                       _Ñ_You Cee Lo Green
# 2494                       _Ñ_You Cee Lo Green
#
#                                         YoutubeSongName  Year  commentCount  \
# 0     【Nightcore】→ 1-800-273-8255 ( Rock Cover ) || ...  2018         500.0
# 1     "Kung Fu Kenny" *FREE* Kendrick Lamar feat Jay...  2018           2.0
# 2     "Matthew 4:44" *FREE* Kanye West feat Jay Z 4:...  2018           2.0
# 3     "Paradise" *FREE* Jay Z 4:44 feat Kendrick Lam...  2018           6.0
# 4                     4:44 Instrumental | Reprod. By Q.  2018         116.0
# 5               JAY-Z Cancels Another 4:44 Tour Concert  2018         392.0
# 6     JAY-Z'S HIP-HOP CAREER IS OVER, NOW TRYING TO ...  2018        1883.0
# 7     JAY-Z: 4:44 Tour Had Reports of Low Ticket Sal...  2018         253.0
# 8     Jay Z - "Numb /Encore" 4:44 Tour Tribute to Ch...  2018          12.0
# 9                               Jay Z - 4:44 | Reaction  2018         350.0
# 10    Jay Z 4:44 Concert, Philadelphia Freedom For M...  2018           5.0
# 11                Jay Z 4:44 Puma Clyde | Mayor Mondays  2018          57.0
# 12    Jay Z Cancels Two '4:44' Shows Due to Technica...  2018         116.0
# 13    Jay Z Pays Tribute To Bone Thugs N Harmony On ...  2018          92.0
# 14    Jay Z Responds to Bob McNair's Controversial '...  2018         207.0
# 15    Jay Z Shouts Out Meek Mill During '4:44' Show ...  2018          85.0
# 16    Jay Z Speaks On Meek Mill At 4:44 Tour "Probat...  2018           6.0
# 17    Jay Z Speaks On Meek Mill's 2-4 Year Prison Se...  2018          12.0
# 18    Jay Z reportedly struggling to sell out some v...  2018        2828.0
# 19    Jay Z's 4:44 Tour - Chicago | Litty!! (CONCERT...  2018          79.0
# 20    Jay Z's 4:44 Tour Allegedly Slow Ticket Sales ...  2018           3.0
# 21           Jay Z's 4:44 Tour Is Failing (I TOLD YALL)  2018           4.0
# 22    Jay Z- Intro/Kill Jay Z/No Church In The Wild/...  2018          54.0
# 23                           Jay Z: 4:44 Tour Live 2017  2018          92.0
# 24                Jay- Z - Smile (Official Video ) 4:44  2018           6.0
# 25    Jay-Z  4:44 Tour - 99 Problems and Big Pimpin'...  2018           1.0
# 26        Jay-Z - "Marcy Me" (The 4:44 Tour - 10/27/17)  2018          14.0
# 27    Jay-Z - "Niggas In Paris" (The 4:44 Tour - 10/...  2018           1.0
# 28              Jay-Z - 4:44 (The 4:44 Tour - 10/27/17)  2018           7.0
# 29                          Jay-Z - 4:44 @ Honda Center  2018           5.0
# ...                                                 ...   ...           ...
# 2465             Cee Lo Green - No One's Gonna Love You  2011           6.0
# 2466               Cee Lo Green - OLD FASHIONED (audio)  2011           8.0
# 2467  Cee Lo Green Ft Melanie Fiona - Fool For You. ...  2011         109.0
# 2468  Cee lo Green ft. Melanie Fiona - Fool for You.wmv  2011        5251.0
# 2469                  Cee lo green - forget you - Clean  2011         272.0
# 2470  Cee-Lo Green - "Fuck You" (Later with Jools Ho...  2011       14763.0
# 2471  Cee-Lo Green - Forget You (fuck you) LIVE on "...  2011         223.0
# 2472                            Cee-Lo Green - Fuck You  2011         522.0
# 2473  CeeLo Green 'Bright Lights Bigger City' OFFICI...  2011        1899.0
# 2474  Ceelo Green - Fuck You | Acapella Cover by The...  2011         199.0
# 2475        Connie Talbot Cee Lo Green Cover Forget You  2011         968.0
# 2476  Fool For You- Cee Lo Green ft. Melanie Fiona L...  2011         434.0
# 2477  Forget You (Cee Lo Green)  -  Jason Chen and M...  2011         510.0
# 2478  Forget You - Cee Lo Green (Cover by Tiffany Al...  2011        1858.0
# 2479  Forget You - Cee Lo Green - Tyler Ward feat Dr...  2011        4756.0
# 2480                   Forget You - Cee-Lo Green Lyrics  2011         316.0
# 2481             Forget You Cee Lo Green Lyrics [CLEAN]  2011         792.0
# 2482  Forget You Cee Lo Green Lyrics [CLEAN] Better ...  2011         568.0
# 2483  Forget You- Cee Lo Green (cover) Megan Nicole ...  2011        1298.0
# 2484                  Forget you - Cee Lo Green (cover)  2011         196.0
# 2485              Fuck You (Cee Lo Green Ukulele Cover)  2011          41.0
# 2486  How to Play Forget You by Cee Lo Green Piano T...  2011         137.0
# 2487  Kung Fu-Fighting Featuring Cee-Lo Green and Ja...  2011          54.0
# 2488            Me Singing "Forget You" by Cee Lo Green  2011         300.0
# 2489            Mia covers "Forget You" by Cee lo Green  2011          43.0
# 2490  Pixie Lott - Forget You - Live Lounge - Cee Lo...  2011          33.0
# 2491    Shucks You (music parody) F*ck You Cee Lo Green  2011         583.0
# 2492  The Blanks do Katy Perry, Cee Lo Green, etc - ...  2011         179.0
# 2493                   William Shatner Sings "F**k You"  2011         312.0
# 2494  X Factor 2011-Chrissie Pitt-Forget You- Cee Lo...  2011        1404.0
#
#       dislikeCount  favoriteCount  likeCount  viewCount
# 0            171.0              0    16651.0   796254.0
# 1              0.0              0        5.0     2455.0
# 2              1.0              0       14.0     3256.0
# 3              0.0              0      116.0     2484.0
# 4             15.0              0     1082.0    51721.0
# 5             56.0              0      890.0    99754.0
# 6           1302.0              0     1793.0   453953.0
# 7            583.0              0    33678.0  2781281.0
# 8              0.0              0      160.0     3992.0
# 9             26.0              0      571.0    10290.0
# 10             9.0              0       44.0     6092.0
# 11            12.0              0      237.0     9586.0
# 12            20.0              0      238.0    14160.0
# 13            10.0              0      291.0     6643.0
# 14            43.0              0      605.0    41600.0
# 15            12.0              0      304.0    13124.0
# 16             0.0              0        8.0     2218.0
# 17            26.0              0       20.0     4890.0
# 18           284.0              0     5441.0   315085.0
# 19             9.0              0      427.0     5661.0
# 20             2.0              0       11.0     4410.0
# 21             0.0              0       17.0     1581.0
# 22             3.0              0      115.0     1724.0
# 23            16.0              0      380.0    66321.0
# 24             0.0              0       72.0     3874.0
# 25             0.0              0       11.0     1887.0
# 26             2.0              0       22.0     2788.0
# 27             0.0              0       14.0     2103.0
# 28             0.0              0       31.0     1471.0
# 29             1.0              0      109.0     2707.0
# ...            ...            ...        ...        ...
# 2465           4.0              0       59.0    25514.0
# 2466           5.0              0       82.0    21332.0
# 2467          12.0              0      859.0    79291.0
# 2468         674.0              0    32920.0  2847420.0
# 2469         149.0              0     2308.0   713106.0
# 2470        1813.0              0    57019.0  3831938.0
# 2471         299.0              0     2906.0  1700815.0
# 2472         117.0              0     6100.0  1541205.0
# 2473         488.0              0    24585.0  3481718.0
# 2474          48.0              0     2158.0   540012.0
# 2475         133.0              0     4617.0   544005.0
# 2476         120.0              0     5031.0  1195682.0
# 2477          91.0              0     3132.0   967141.0
# 2478         167.0              0    21099.0  1835723.0
# 2479         174.0              0    47527.0  1218627.0
# 2480         262.0              0     3951.0   885838.0
# 2481         143.0              0     5017.0   559057.0
# 2482         366.0              0    12417.0  2186105.0
# 2483         358.0              0    13553.0  1845843.0
# 2484          64.0              0     2625.0   648608.0
# 2485          22.0              0      117.0    23809.0
# 2486          39.0              0     1513.0   383274.0
# 2487           9.0              0      311.0    39090.0
# 2488         112.0              0     1690.0  1269465.0
# 2489           9.0              0      740.0    24467.0
# 2490          18.0              0      448.0    97209.0
# 2491          86.0              0     3464.0   721078.0
# 2492          83.0              0     1191.0   963373.0
# 2493         156.0              0     2369.0  1039512.0
# 2494         245.0              0     6463.0   576488.0
#
# [2495 rows x 8 columns]

# %%
song_stats = renamed_stats_df.groupby('Song').agg({'commentCount': np.sum , 
                                                   'dislikeCount': np.sum, 
                                                   'favoriteCount': np.sum, 
                                                   'likeCount': np.sum, 
                                                   'viewCount': np.sum, 
                                                   'Year': np.mean}).reset_index()
song_stats.head()
# Out:
#                                        Song  commentCount  dislikeCount  \
# 0  1-800-273-8255 Logic Alessia Cara Khalid         500.0         171.0
# 1                                4:44 JAY-Z       12382.0        3917.0
# 2                      7 Years Lukas Graham       30840.0        9818.0
# 3                              Adorn Miguel       49240.0        7726.0
# 4        All About That Bass Meghan Trainor      638215.0      759825.0
#
#    favoriteCount   likeCount     viewCount  Year
# 0              0     16651.0  7.962540e+05  2018
# 1              0     64187.0  5.050967e+06  2018
# 2              0    341240.0  2.313100e+07  2017
# 3              0    443670.0  4.165320e+07  2013
# 4              0  10353159.0  2.646450e+09  2015

# %%
# Merge song stats with rev_nominees temp

song_stats.head()

merge_songs_list = song_stats.merge(rev_nominees_temp, how="outer", on="Song")

merge_songs_list = merge_songs_list[["Year","likeCount", "viewCount", "SONG OF THE YEAR"]]
merge_songs_list = merge_songs_list.rename(columns={"SONG OF THE YEAR":"Song"})

merge_songs_list.head()
# Out:
#      Year   likeCount     viewCount                 Song
# 0  2018.0     16651.0  7.962540e+05       1-800-273-8255
# 1  2018.0     64187.0  5.050967e+06                 4:44
# 2  2017.0    341240.0  2.313100e+07              7 Years
# 3  2013.0    443670.0  4.165320e+07                Adorn
# 4  2015.0  10353159.0  2.646450e+09  All About That Bass

# %%
#Import the grammy winner's list

rev_winners_list = rev_winners_list.rename(columns={"SONG OF THE YEAR":"Song"})

rev_winners_list.head()

#Merge song list and winners list

SOY_final_list = merge_songs_list.merge(rev_winners_list, how="outer", on="Song")

#Replace blanks with L and the rest as W

SOY_final_list['SOY ARTIST'].fillna("L", inplace=True)

SOY_final_list["Color"] = ''
winner_color = []

winner_tag = SOY_final_list["SOY ARTIST"]

for index, i in enumerate(winner_tag):
    if i !='L':
        winner_tag[index]="W"
    else:
        winner_tag[index]="L"
        
for i in winner_tag:
    if i == "L":
        winner_color.append("blue")
    else:
        winner_color.append("red")

SOY_final_list["Color"] = winner_color
        
SOY_final_list
# Out:
# /Users/jenny/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jenny/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       Year   likeCount     viewCount                                Song  \
# 0   2018.0     16651.0  7.962540e+05                      1-800-273-8255
# 1   2018.0     64187.0  5.050967e+06                                4:44
# 2   2017.0    341240.0  2.313100e+07                             7 Years
# 3   2013.0    443670.0  4.165320e+07                               Adorn
# 4   2015.0  10353159.0  2.646450e+09                 All About That Bass
# 5   2012.0       371.0  8.621400e+04                   All Of The Lights
# 6   2016.0    506349.0  5.956152e+07                             Alright
# 7   2009.0     62059.0  1.423518e+07                        American Boy
# 8   2008.0    468851.0  1.074256e+08                    Before He Cheats
# 9   2011.0    420849.0  8.918381e+07                 Beg Steal Or Borrow
# 10  2016.0    281790.0  2.916894e+07                         Blank Space
# 11  2013.0    903149.0  1.287608e+08                       Call Me Maybe
# 12  2015.0  10203896.0  2.204013e+09                          Chandelier
# 13  2009.0    126913.0  1.965597e+07                   Chasing Pavements
# 14  2018.0    101929.0  2.495576e+06                           Despacito
# 15  2017.0    999158.0  1.059218e+08                           Formation
# 16  2016.0    242865.0  2.817316e+07                          Girl Crush
# 17  2012.0    226296.0  3.110946e+07                             Grenade
# 18  2017.0    825678.0  8.069451e+07                               Hello
# 19  2008.0    134596.0  3.056505e+07                   Hey There Delilah
# 20  2012.0   2777833.0  4.738186e+08                            Holocene
# 21  2017.0    368232.0  3.484400e+07              I Took A Pill In Ibiza
# 22  2009.0    181184.0  4.721691e+07                           I'm Yours
# 23  2018.0     48526.0  2.248050e+06                              Issues
# 24  2014.0    553316.0  8.370159e+07               Just Give Me a Reason
# 25  2008.0     93859.0  2.200082e+07                         Like A Star
# 26  2014.0   6614194.0  2.273068e+09                Locked Out of Heaven
# 27  2009.0    114166.0  2.290500e+07                           Love Song
# 28  2011.0   1431461.0  2.784769e+08                Love The Way You Lie
# 29  2017.0   1073852.0  8.065600e+07                       Love Yourself
# 30  2011.0     12999.0  2.348612e+06                        Need You Now
# 31  2010.0   2633180.0  6.723405e+08                          Poker Face
# 32  2010.0    670020.0  1.221469e+08                        Pretty Wings
# 33  2008.0     30374.0  1.467616e+07                               Rehab
# 34  2014.0   1340367.0  2.285257e+08                                Roar
# 35  2012.0    927455.0  1.364424e+08                 Rolling In The Deep
# 36  2014.0   3184758.0  3.424665e+08                              Royals
# 37  2014.0     19579.0  2.701524e+06                           Same Love
# 38  2016.0    489909.0  4.980531e+07                       See You Again
# 39  2015.0   2538764.0  3.365972e+08                        Shake It Off
# 40  2010.0   3649015.0  1.353269e+09    Single Ladies (Put A Ring On It)
# 41  2015.0   1517800.0  1.585427e+08    Stay With Me (Darkchild Version)
# 42  2015.0    723571.0  5.232437e+07                   Take Me To Chursh
# 43  2018.0     56637.0  1.750276e+06                  That's What I Like
# 44  2013.0    638555.0  6.385591e+07                          The A Team
# 45  2012.0   2723833.0  7.309109e+08                            The Cave
# 46  2011.0    767955.0  2.077886e+08             The House That Built Me
# 47  2016.0    333378.0  3.446132e+07                   Thinking Out Loud
# 48  2008.0      1676.0  1.069729e+06                            Umbrella
# 49  2010.0   1157272.0  3.000830e+08                        Use Somebody
# 50  2009.0     81683.0  2.018509e+07                        Viva la Vida
# 51  2013.0     29896.0  4.555457e+06                        We Are Young
# 52  2010.0     96772.0  1.969874e+07                  You Belong With Me
# 53  2011.0    459353.0  5.712220e+07                              _Ñ_You
# 54     NaN         NaN           NaN  Stronger (What Doesn_Ñét Kill You)
# 55     NaN         NaN           NaN                                 NaN
#
#    SOY ARTIST Color
# 0           L  blue
# 1           L  blue
# 2           L  blue
# 3           L  blue
# 4           L  blue
# 5           L  blue
# 6           L  blue
# 7           L  blue
# 8           L  blue
# 9           L  blue
# 10          L  blue
# 11          L  blue
# 12          L  blue
# 13          L  blue
# 14          L  blue
# 15          L  blue
# 16          L  blue
# 17          L  blue
# 18          W   red
# 19          L  blue
# 20          L  blue
# 21          L  blue
# 22          L  blue
# 23          L  blue
# 24          L  blue
# 25          L  blue
# 26          L  blue
# 27          L  blue
# 28          L  blue
# 29          L  blue
# 30          W   red
# 31          L  blue
# 32          L  blue
# 33          W   red
# 34          L  blue
# 35          W   red
# 36          W   red
# 37          L  blue
# 38          L  blue
# 39          L  blue
# 40          W   red
# 41          W   red
# 42          L  blue
# 43          L  blue
# 44          L  blue
# 45          L  blue
# 46          L  blue
# 47          W   red
# 48          L  blue
# 49          L  blue
# 50          W   red
# 51          W   red
# 52          L  blue
# 53          L  blue
# 54          L  blue
# 55          L  blue

# %%
# Create separate dataframes per year

SOY_dict = {}

data_years = [2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008]

for year in data_years:
    
    SOY_dict[year] = SOY_final_list.loc[SOY_final_list["Year"]==year]

SOY_dict[2017]
# Out:
#       Year  likeCount    viewCount                    Song SOY ARTIST Color
# 2   2017.0   341240.0   23131005.0                 7 Years          L  blue
# 15  2017.0   999158.0  105921799.0               Formation          L  blue
# 18  2017.0   825678.0   80694514.0                   Hello          W   red
# 21  2017.0   368232.0   34844004.0  I Took A Pill In Ibiza          L  blue
# 29  2017.0  1073852.0   80656003.0           Love Yourself          L  blue

# %%
print(song_stats.dtypes)
# Out:
# Song              object
# commentCount     float64
# dislikeCount     float64
# favoriteCount      int64
# likeCount        float64
# viewCount        float64
# Year               int64
# dtype: object

# %%
for year in data_years:

    weighted_likecount = SOY_dict[year]['likeCount']*0.5
    weighted_viewcount = SOY_dict[year]['viewCount']*0.5

    weighted_total = weighted_likecount + weighted_viewcount

    SOY_dict[year]['Weighted_score'] = weighted_total
    
SOY_dict[2016]
# Out:
# /Users/jenny/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       Year  likeCount   viewCount               Song SOY ARTIST Color  \
# 6   2016.0   506349.0  59561518.0            Alright          L  blue
# 10  2016.0   281790.0  29168935.0        Blank Space          L  blue
# 16  2016.0   242865.0  28173158.0         Girl Crush          L  blue
# 38  2016.0   489909.0  49805313.0      See You Again          L  blue
# 47  2016.0   333378.0  34461318.0  Thinking Out Loud          W   red
#
#     Weighted_score
# 6       30033933.5
# 10      14725362.5
# 16      14208011.5
# 38      25147611.0
# 47      17397348.0

# %%
for year in data_years:
    x_values = np.arange(len(SOY_dict[year]))
    weighted_score = SOY_dict[year]['Weighted_score']
    songs = SOY_dict[year]['Song']
    plot_color = SOY_dict[year]['Color']
    plt.bar(x_values, weighted_score, tick_label = songs, color=plot_color)
    plt.title(f'Weighted score from {year} Song of the Year')
    plt.ylabel('Weighted count')
    plt.xlabel('Song name')
    plt.xticks(rotation=45)
    plt.gcf().subplots_adjust(bottom=0.4)
    plt.savefig(f'SOY_weightedscore_{year}.png')
    plt.show()

# %%
for year in data_years:
    x_values = np.arange(len(SOY_dict[year]))
    weighted_score = SOY_dict[year]['Weighted_score']
    songs = SOY_dict[year]['Song']
    plot_color = SOY_dict[year]['Color']
    plt.bar(x_values, weighted_score, tick_label = songs, color=plot_color)
    plt.title(f'Like Counts from {year} Song of the Year')
    plt.ylabel('Count by likes')
    plt.xlabel('Song name')
    plt.xticks(rotation=45)
    plt.gcf().subplots_adjust(bottom=0.4)
    plt.savefig(f'SOY_likecount_{year}.png')
    plt.show()

# %%
for year in data_years:
    x_values = np.arange(len(SOY_dict[year]))
    weighted_score = SOY_dict[year]['Weighted_score']
    songs = SOY_dict[year]['Song']
    plot_color = SOY_dict[year]['Color']
    plt.bar(x_values, weighted_score, tick_label = songs, color=plot_color)
    plt.title(f'View Counts from {year} Song of the Year')
    plt.ylabel('Count by views')
    plt.xlabel('Song name')
    plt.xticks(rotation=45)
    plt.gcf().subplots_adjust(bottom=0.4)
    plt.savefig(f'SOY_viewcount_{year}.png')
    plt.show()
