# %%
# Import Dependencies
import matplotlib.pyplot as plt
import requests as req
import pandas as pd
import numpy as np
import seaborn
import random
import json

# %%
nominees_list = pd.DataFrame.from_csv("/Users/gar/GitFiles/Team5/Updated_List_Nominations.csv", index_col=None, encoding='utf-8')

# %%
nominees_list.head()
# Out:
#    Year RECORD OF THE YEAR                             ROY ARTIST  \
# 0  2018            Redbone                       Childish Gambino
# 1  2018          Despacito  Luis Fonsi Daddy Yankee Justin Bieber
# 2  2018  The Story of O.J.                                  JAY-Z
# 3  2018             Humble                         Kendrick Lamar
# 4  2018          24k Magic                             Bruno Mars
#
#   BEST NEW ARTIST    SONG OF THE YEAR                             SOY ARTIST
# 0    Alessia Cara           Despacito  Luis Fonsi Daddy Yankee Justin Bieber
# 1          Khalid                4:44                                  JAY-Z
# 2    Lil Uzi Vert              Issues                         Julia Michaels
# 3  Julia Michaels      1-800-273-8255              Logic Alessia Cara Khalid
# 4             SZA  That's What I Like                             Bruno Mars

# %%
# Combine related columns and create a new combined column

nominees_list['ROY Combined'] = nominees_list['RECORD OF THE YEAR'] + " " + nominees_list['ROY ARTIST']
nominees_list['SOY Combined'] = nominees_list['SONG OF THE YEAR'] + " " + nominees_list['SOY ARTIST']

nominees_list.head()

# Generate a new list with combined data

rev_nominees_list = nominees_list[["Year", "ROY Combined", "SOY Combined", "BEST NEW ARTIST"]]

rev_nominees_list.head()
# Out:
#    Year                                     ROY Combined  \
# 0  2018                         Redbone Childish Gambino
# 1  2018  Despacito Luis Fonsi Daddy Yankee Justin Bieber
# 2  2018                          The Story of O.J. JAY-Z
# 3  2018                            Humble Kendrick Lamar
# 4  2018                             24k Magic Bruno Mars
#
#                                       SOY Combined BEST NEW ARTIST
# 0  Despacito Luis Fonsi Daddy Yankee Justin Bieber    Alessia Cara
# 1                                       4:44 JAY-Z          Khalid
# 2                            Issues Julia Michaels    Lil Uzi Vert
# 3         1-800-273-8255 Logic Alessia Cara Khalid  Julia Michaels
# 4                    That's What I Like Bruno Mars             SZA

# %%
#Create a DataFrame for the Nominees list

rev_nominees_list_df = pd.DataFrame(rev_nominees_list)
rev_nominees_list_df.head()

#Split the DataFrame by category
#Record of the Year
records_list_df = rev_nominees_list_df[["Year", "ROY Combined"]]
#records_list_df.head()

#Split the DataFrame by category
new_artist_list_df = rev_nominees_list_df[["Year", "BEST NEW ARTIST"]]
print(new_artist_list_df.head())

#Split the DataFrame by category
song_list_df = rev_nominees_list_df[["Year", "SOY Combined"]]
#song_list_df.head()
# Out:
#    Year BEST NEW ARTIST
# 0  2018    Alessia Cara
# 1  2018          Khalid
# 2  2018    Lil Uzi Vert
# 3  2018  Julia Michaels
# 4  2018             SZA

# %%
years = ["2017", "2016", "2015", "2014", "2013", "2012", "2011", "2010", "2009", "2008"]

search_data = {'Artist':[],
               'Year':[],
               'Title':[],
               'VideoId':[],
               'Channel_Title':[],
               'ChannelId':[],
               'PublishedAt':[]}

for year in years:
    year = int(year)
    pub_after = year - 1
    pub_before = year
    
    url = 'https://www.googleapis.com/youtube/v3/search'

    api_key = 'AIzaSyBIsDwNMWPe4ZMVlpVcPpZTVaM45h3Umdo'

    artist = new_artist_list_df.loc[(new_artist_list_df['Year']==year)]
    artist = artist['BEST NEW ARTIST']

    params = {'key': 'AIzaSyBJUQCRS-O5wAMAoILxVo8THZf9D4Ex3Zc',
             'part': 'snippet',
             'maxResults': 50,
             'publishedAfter': f'{pub_after}-10-01T00:00:00Z',
             'publishedBefore': f'{pub_before}-09-30T00:00:00Z',
             'order': 'viewCount',
             'q': ''}
    
    for search_term in artist:
        params['q'] = search_term
        response = req.get(url, params=params).json()
        for search_result in response['items']:
            try:
                search_data['Artist'].append(search_term)
                search_data['Year'].append(year)
                search_data['Title'].append(search_result['snippet']['title'])
                search_data['VideoId'].append(search_result['id']['videoId'])
                search_data['Channel_Title'].append(search_result['snippet']['channelTitle'])
                search_data['ChannelId'].append(search_result['snippet']['channelId'])
                search_data['PublishedAt'].append(search_result['snippet']['publishedAt'])
            except KeyError:
                print("Missing videoID")
                
search_data = pd.DataFrame.from_dict(search_data, orient='index').transpose()
    
test_df = pd.DataFrame(search_data)

title_vid = test_df[['Artist', 'Title', 'VideoId', 'Year']]
    
url_vid = 'https://www.googleapis.com/youtube/v3/videos'

params = {'key': 'AIzaSyBIsDwNMWPe4ZMVlpVcPpZTVaM45h3Umdo',
          'part': 'statistics',
          'id': ''}

grammy_stats_df = {}

for artist, title, vid_id, year in title_vid.itertuples(index=False):
    try:
        params['id'] = vid_id
        response = req.get(url_vid, params=params).json()
        grammy_stats_df[artist, title, year] = response['items'][0]['statistics']
    except KeyError:
        print(title + " is missing the videoID.")
            
artist_stats_df = pd.DataFrame()
artist_stats_df = artist_stats_df.append(pd.DataFrame(grammy_stats_df).transpose())
artist_stats_df.head()
# Out:
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# Missing videoID
# TRL Recap! is missing the videoID.
# Love Story (of Taylor Swift, by www.GuitarTutee.com) is missing the videoID.
# Taylor Swift and Kellie Pickler Duet 5/24 is missing the videoID.
# Taylor Swift~Shouldv'e said no! is missing the videoID.
# Taylor Swift Comments on Purity Rings is missing the videoID.
# Taylor Swift - Perfectly Good Heart is missing the videoID.
# 4 Year Old sings "Our Song" by Taylor Swift is missing the videoID.
# Taylor Swift's Back-to-School Shopping Tips is missing the videoID.
# taylor swift-christmas' when you were mine is missing the videoID.
# Fearless Lyrics Taylor Swift is missing the videoID.
# 9 year old Lexi sings Taylor Swift "Our Song" on stage is missing the videoID.
# Taylor Swift - 7 Things is missing the videoID.
# Beautiful Eyes-Taylor Swift is missing the videoID.
# Umbrella By:Taylor swift :) is missing the videoID.
# Jonas Brothers & Taylor Swift - Should've Said No (Take One) is missing the videoID.
# Love Story-Taylor Swift vid+tutorial is missing the videoID.
# Tear Drops On My Guitar - Taylor Swift www.guitartutee.com is missing the videoID.
# Teardrops On My Old Car! (Teardrops On My Guitar! Taylor Swift Parody!) is missing the videoID.
# Brad Paisley pranks Taylor Swift with "Behind the Music" is missing the videoID.
# =Taylor Swift - Christmas Must Be Something More w. lyrics is missing the videoID.
# Amy Winehouse - Valery is missing the videoID.
# Amy Winehouse, Valerie and lyrics is missing the videoID.
# Amy Winehouse - Wake Up Alone is missing the videoID.
# Amy Winehouse - Valerie (Acoustic, Live, Best Quality) is missing the videoID.
# Valerie (Amy Winehouse) is missing the videoID.
# Momento Amy Winehouse 2 - Pânico na Tv 14/09/08 is missing the videoID.
# Amy Winehouse - Wake Up Alone is missing the videoID.
# Amy Winehouse- Valerie (Best Version) is missing the videoID.
# Amy Winehouse - Rock in Rio 2008 - some bizarre moments / R.I.P. is missing the videoID.
# Amy Winehouse's Disastrous Face is missing the videoID.
# Amy Winehouse - Addicted is missing the videoID.
# Amy Winehouse - Just Friends is missing the videoID.
# Amy Winehouse Punches a Fan! Glastonbury 08 is missing the videoID.
# Amy Winehouse - To Know Him Is To Love Him is missing the videoID.
# Amy Winehouse - Love Is A Losing Game [Official Music Video] is missing the videoID.
# Amy Winehouse - Back to Black (Live Acoustic - SXSW) is missing the videoID.
# Amy Winehouse-Monkey Man is missing the videoID.
# _Amy Winehouse - Me And Mr. Jones. (with lyrics) is missing the videoID.
# Amy Winehouse - I Saw Mummy Kissing Santa Claus is missing the videoID.
# Amy Winehouse live Zurich - snooping is missing the videoID.
# Amy Winehouse - Will you still love me tomorrow is missing the videoID.
# Mark Ronson feat Amy Winehouse - Valerie is missing the videoID.
# Amy Winehouse Is Losing More Than Her Mind is missing the videoID.
# Amy Winehouse 'Love is a Losing Game' Lyrics is missing the videoID.
# Amy Winehouse - Me & Mr Jones (Live - AOL) is missing the videoID.
# Amy Winehouse - Rehab - With Lyrics is missing the videoID.
# Amy Winehouse "Rehab (live)" is missing the videoID.
# Amy Winehouse - before and after is missing the videoID.
# Amy Grammy Rehab Winehouse is missing the videoID.
# Amy Winehouse live - Back To Black (Vodafone Somerset House) is missing the videoID.
# Amy Winehouse - Love Is A Losing Game (Live) is missing the videoID.
# Amy winehouse- You know I´m no good(legendado) is missing the videoID.
# Amy Winehouse - Back To Black [Live in London] is missing the videoID.
# Amy Winehouse - Stronger than me [Live On Jools Holland] is missing the videoID.
# Amy Winehouse - He Can Only Hold Her (Live - AOL) is missing the videoID.
# Amy Winehouse - Back to Black @ HMH Amsterdam is missing the videoID.
# Amy Winehouse - Frank Deluxe Edition is missing the videoID.
# Amy Winehouse - Monkey Man is missing the videoID.
# Amy winehouse drogandose en un concierto! is missing the videoID.
# Amy Winehouse - to Know him is to Love him / special edition is missing the videoID.
# Amy Winehouse - You Know I'm No Good (Original Demo) is missing the videoID.
# Amy Winehouse &  Rolling Stones  -  Ain't to Proud to Beg is missing the videoID.
# Amy Winehouse - Stronger Than Me is missing the videoID.
# Amy Winehouse - October Song (Live) is missing the videoID.
# AMY WINEHOUSE BEFORE AND AFTER DRUGS is missing the videoID.
# Florence Foresti est Amy Winehouse: Festival Juste pour rire is missing the videoID.
# Amy Winehouse - Love Is A Losing Game (Original Demo) is missing the videoID.
# Back to Black - Amy Winehouse Lyrics is missing the videoID.
# AMY WINEHOUSE EYE LINER MAKEUP INSPIRED LOOK is missing the videoID.
# Amy Winehouse - All My Lovin' is missing the videoID.
#                                                    commentCount dislikeCount  \
# (Kelsea Ballerini, Kelsea Ballerini - Legends, ...         2276         2448
# (Kelsea Ballerini, Kelsea Ballerini - Yeah Boy,...         2257         2044
# (Kelsea Ballerini, Jason Aldean - First Time Ag...          261          764
# (Kelsea Ballerini, Charades with Jessica Biel, ...          497          167
# (Kelsea Ballerini, Kelsea Ballerini - Legends -...         4587          796
#
#                                                    favoriteCount likeCount  \
# (Kelsea Ballerini, Kelsea Ballerini - Legends, ...             0     42663
# (Kelsea Ballerini, Kelsea Ballerini - Yeah Boy,...             0     32588
# (Kelsea Ballerini, Jason Aldean - First Time Ag...             0     13910
# (Kelsea Ballerini, Charades with Jessica Biel, ...             0      8711
# (Kelsea Ballerini, Kelsea Ballerini - Legends -...             0     44806
#
#                                                    viewCount
# (Kelsea Ballerini, Kelsea Ballerini - Legends, ...   7679516
# (Kelsea Ballerini, Kelsea Ballerini - Yeah Boy,...   6003089
# (Kelsea Ballerini, Jason Aldean - First Time Ag...   2245808
# (Kelsea Ballerini, Charades with Jessica Biel, ...    996294
# (Kelsea Ballerini, Kelsea Ballerini - Legends -...    942144

# %%
artist_stats_df
# Out:
#                                                    commentCount dislikeCount  \
# (Kelsea Ballerini, Kelsea Ballerini - Legends, ...         2276         2448
# (Kelsea Ballerini, Kelsea Ballerini - Yeah Boy,...         2257         2044
# (Kelsea Ballerini, Jason Aldean - First Time Ag...          261          764
# (Kelsea Ballerini, Charades with Jessica Biel, ...          497          167
# (Kelsea Ballerini, Kelsea Ballerini - Legends -...         4587          796
# (Kelsea Ballerini, Kelsea Ballerini - Legends (...          250          199
# (Kelsea Ballerini, Legends - Kelsea Ballerini (...          257          162
# (Kelsea Ballerini, "Till The World Ends" Jamie ...           95           47
# (Kelsea Ballerini, Lady Antebellum - You're Sti...          197          101
# (Kelsea Ballerini, Kelsea Ballerini - High Scho...          199           93
# (Kelsea Ballerini, High School - Kelsea Balleri...          130           64
# (Kelsea Ballerini, "Oops!...I Did It Again" Kel...           29           37
# (Kelsea Ballerini, Lukas Graham / Kelsea Baller...          209          185
# (Kelsea Ballerini, Mackenzie Ziegler's cover of...          109           31
# (Kelsea Ballerini, Shania Twain -Kelsea Balleri...           63           36
# (Kelsea Ballerini, Unapologetically - Kelsea Ba...           32           34
# (Kelsea Ballerini, Kelsea Ballerini Performs 'U...          123           82
# (Kelsea Ballerini, Underage - Kelsea Ballerini,...           12           17
# (Kelsea Ballerini, Kelsea Ballerini - Unapologe...           56           16
# (Kelsea Ballerini, OPRY 360: Kelsea Ballerini -...           21           25
# (Kelsea Ballerini, taylor swift ft kelsea balle...           37           19
# (Kelsea Ballerini, 5 Reasons to Love Kelsea Bal...            2            4
# (Kelsea Ballerini, Kelsea Ballerini Covers Blak...           11            4
# (Kelsea Ballerini, Shania Twain and Kelsea Ball...            4            2
# (Kelsea Ballerini, "Yeah Boy" Kelsea Ballerini ...           50           68
# (Kelsea Ballerini, Peter Pan -  Kelsea Ballerin...          155           11
# (Kelsea Ballerini, Legends - Kelsea Ballerini, ...           21           49
# (Kelsea Ballerini, Kelsea Ballerini - Yeah Boy ...           14            7
# (Kelsea Ballerini, Kelsea Ballerini's Home Tour...           11            7
# (Kelsea Ballerini, Internet Pop Quiz: Kelsea Ba...           55           24
# ...                                                         ...          ...
# (Taylor Swift, Taylor Swift - Should've Said No...          823          154
# (Taylor Swift, Music Videos, 2008)                          360          117
# (Taylor Swift, JOE JONAS AND TAYLOR SWIFT KISSI...         1406         3858
# (Taylor Swift, TAYLOR SWIFT ~TEARDROPS ON MY GU...          354          155
# (Taylor Swift, Taylor Swift - Seventeen Cover C...          669           45
# (Taylor Swift, Our Song - Taylor Swift (Acousti...          696          203
# (Taylor Swift, Taylor Swift- "Should've said No...          465           98
# (Taylor Swift, "Picture to burn" (With lyrics),...          924          424
